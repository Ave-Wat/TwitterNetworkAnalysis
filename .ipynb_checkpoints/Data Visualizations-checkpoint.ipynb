# %%
import pandas as pd
import numpy
import networkx
import matplotlib
import csv
import os
from collections import defaultdict

# %%
# Remove duplicates

# %%
# Create dictionary of users and their following list
directory = "/Users/teaganjohnson/Desktop/TwitterNetworkAnalysis/data/"
usernamesDict = defaultdict(list)
#for file in directory:
with open(directory+"usernames10.csv") as f:
    csv_reader = csv.reader(f, delimiter=',')
    for row in csv_reader:
        if row[0] not in usernamesDict.keys():
            usernamesDict[row[0]] = [row[1]]
        else:
            if row[1] not in usernamesDict[row[0]]:
                usernamesDict[row[0]].append(row[1])
            else:
                print("Duplicate!")
            
print(usernamesDict)
# Out:
# defaultdict(<class 'list'>, {'manisha_111': ['sachin_rt', 'anjanisri55', 'priyasethibjp', 'poojabishnoi36', 'shubhammehrabjp', 'AxisBankSupport', 'Shamsher_IPS', 'khanak8181', 'ritikapanditji', 'DrSandhyaTiwari', 'TooterDotIn', 'Real_Kanak_', 'vishalurl', 'BarackObama', 'DEOVADODARA', 'JoeBiden', 'KamalaHarris', 'iChiragPaswan', 'Tejasvi_Surya', 'KanganaTeam', 'Cristiano', 'girirajsinghbjp', 'RNagothu', 'ImranKhanPTI', 'DrRPNishank', 'PrakashJavdekar', 'PiyushsainiBjp', 'AHindinews', 'ShankersinhBapu', 'globaltimesnews', 'ChinaDaily', 'GPCB_Ankleshwar', 'VadodaraUpdates', '022puneet', 'myvoltas', 'iamVadodara', 'sudhirchaudhary', 'vnehra', 'Vadcitypolice', 'LahriSunil', 'arungovil12', 'DDNewsGujarati', 'SetuAarogya', 'PIBHomeAffairs', 'rajpd28', 'PathakUmangi', 'PIBAhmedabad', 'covid19indiaorg', 'DrRamOfficial', 'CarebyHDFC_HL', 'HomeLoansByHDFC', 'BNODesk', 'ConnectGujarat', 'AshwiniUpadhyay', 'RohiniShah73', 'I_M_Shreyaa', 'InfoVadodaraGoG', 'InfoGujarat', 'DrGudiyaa', 'Great_Suchita', 'ourvadodara', 'VMCVadodara', 'CollectorVad', 'NHMGujarat', 'JayantiRavi', 'ZEE5News', 'GujHFWDept', 'MoHFW_GUJARAT', 'CMOGuj', 'MoHFW_INDIA', 'abpasmitatv', 'sandeshnews', 'PakPMO', 'unkonfined', 'lokarlorajniti', 'SachinPilot', 'JM_Scindia', 'aashi_871', 'smritiirani', 'Shweta19969561', 'VasundharaBJP', 'WeREnterprising', 'gautam_adani', 'FLOTUS45', 'IvankaTrump', 'DonaldJTrumpJr', 'being_Ajay_', 'drsanjeevbalyan', 'impreetsbakshi', 'WHO', 'dsr_punadiya', 'VinitMalviyaBJP', 'Raniiagrwal', 'AmitShahOffice', 'Sudhir_mishrr', 'iAmNehaKakkar', 'ideveshsharmaa', 'JPNadda', 'arunbajpairajan', 'theworldindex', 'engineers_feed', 'gunjajain4', 'GujaratHistory', 'lovehappiness__', 'ssingapuri', 'AjayPandey__', 'namomerchandise', 'feelTHEnature_', 'YRDeshmukh', 'AroundOMedia', 'LeadingWPassion', 'KailashOnline', 'UttarPradesh75', 'spectatorindex', 'ANI', 'AmitKalrajOffc', 'DrDishaJasani', 'raviranabjp', 'cop_anirudha', 'harshishettyan', 'rashtrapatibhvn', 'jspandey_', 'Nilum_KnockIOT', 'ProudHindu9', 'snehasneha173', 'RSSholankey', 'snikhil_social', 'anandmahindra', 'TheKashmiriLife', 'ARYNEWSOFFICIAL', 'dave_neel', 'nidhinimitt', 'Goldenthrust', 'RKSinhaBJP', 'AlokTiwari9335', 'BH_Purohit', 'VasudevDevnani', 'News18India', 'TcGehlotOffice', 'MeraNewsHindi', 'AnupamPKher', 'BJP4Gujarat', 'DeshGujaratG', 'aajtak', 'Mamta_Sharma_', 'MUKESHDESWAL3', 'BJP4India', 'ippatel', 'PMOIndia', '24hourssuccess', 'NitishKumar', 'SharmaKhemchand', 'aneeta369', 'OfficeOfRKSingh', 'News18Guj', 'ManojTiwariMP', 'amritabhinder', 'nsitharamanoffc', 'fearlessmotivat', 'TheRenouncer', 'cooladitaya', '01Karn', 'Avantika_23', 'DurgaMenon', 'RahulGandhi', 'uttamkrbhardwaj', 'TheAlpesh_AB', 'iamfearlesssoul', 'VishalBhardiya', 'iPraveendixit', 'pushpendra__kul', 'DhrumilBJP', 'KapilMishra_IND', 'circuitkiller', 'India_Policy', 'NaharAshok', 'manji_ahir', 'ThackerNikhil', 'jatanacharya', 'murli_dhar', 'Indianit07', 'RishiMishra_', 'iSengarAjayy', 'AzizullahBugti', 'SureshM46', 'AmitShah4BJP', 'ajaybhattiwal', 'kapil_kausik', 'YogiDevnath2', 'samarsanatan', 'Jadeja__Sd', 'milisilichilli', 'chintanvedant', 'sanghaviharsh', 'jaiprakashshah2', 'BhagwaBalak', 'JhaRahul_Bihar', 'DigitalGirish', 'iGyanendraGiri', 'VRamanuj', 'iam_manojgoenka', 'imaheshgupta', 'dilipjain1979', 'PcMNavy', 'drpwndutta', 'VishnuDhanuka', 'DDNewsHindi', 'KetanGondalia99', 'HarshilBhuria', 'jyotikatharia', 'parthusoni', 'ManojGoelBJP', 'Harvansh_Batra', 'ppagarwal', 'Sanjay_Vis', 'iShubhamkashi', 'RaghvendraLive', 'AShetty999', 'varshasinghmcx', 'DKR1977', 'SureshRanaBJP', 'myogiadityanath', 'sushilkedia', 'iPankajShukla', 'samvadplus', 'TCGEHLOT', 'PiyushPatelBJP', 'IntolerantMano2', 'AshiWords', 'dryadusingh', 'jeetensingh', 'JThakers', 'ivishalthacker', 'praveen_bajpai', 'RajkumaarPandey', 'tv9gujarati', 'iAbhiAcharya', 'Sumitrabjp', 'nikhildadhich', 'IEX_India_', 'VINEET_KAKA', 'Gravim71', 'SaffronSangh', '_KyaChahteHo', 'prabudhbalak', 'mshiteshmohan', 'prafulkpatel', 'draksbond', 'AvinaashKTC', 'tyagi_ ...
